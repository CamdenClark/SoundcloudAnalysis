# %% [markdown]
# Soundcloud comments, especially on the most popular tracks, are pretty obnoxious. There's a toxic mix of self-promotion and links to external phishing sites.
#
# Can we use similar techniques from email spam filtering techniques to classify what kind of comments are spam?
#
# First, let's grab some comments from a popular track. I'm going to attempt to manually label them using the soundcloud community guidelines: https://soundcloud.com/community-guidelines I'll be interpreting them pretty liberally to include any blatant self-promotion or external phishing/marketing sites.

# %%
import time
import soundcloud

# create a client object with your app credentials
client = soundcloud.Client(client_id='85d3857863f87e52fc6f3a48e11dead7')

slippery = client.get('/resolve', url="https://soundcloud.com/migosatl/slippery-feat-gucci-mane")
slippery.id
# Out:
# 304747566

# %%
next_comments = client.get('/tracks/' + str(slippery.id) + '/comments', linked_partitioning = 1)
final_comment_list = next_comments.obj['collection']
final_page = False
while not final_page:
    next_comments = client.get(next_comments.obj['next_href'][26:])
    final_comment_list = final_comment_list + next_comments.obj['collection']
    if not 'next_href' in next_comments.keys():
        final_page = True

# %% [markdown]
# Well, I would call the majority of these comments pretty low-quality. However, I'm not into broad censorship, so I'm only interested in removing the that are blatant spam.
#
# But first let's put these comments into a pandas dataframe. I'm also going to import the timestamp, which I think might be useful to the model, and we can examine everything later.

# %%
import pandas as pd
train_comments = pd.DataFrame([[comment_obj['id'],comment_obj['body'],
                                comment_obj['timestamp'],slippery_track.obj['duration']]
                               for comment_obj in final_comment_list],
                               columns=['id','body','timestamp','track_length'])

# %%
import numpy as np
train_comments['spam'] = 0
train_comments
# Out:
#             id                                               body  timestamp  \
# 0    334946601  E­­v­­e­­r­­y­­o­­n­­e ­­c­­a­­n m­­a­­k­­e ­­...     293741
# 1    334937543  quavo on the come up wit these choruses https:...      15758
# 2    334927198               slippery she not to be my wife to be     118241
# 3    334903656  check out this new beat made for rappers! http...     185818
# 4    334901198                                                Lol      94368
# 5    334896296  MASTAPIECE Are The Next Aritst Out of Houston!...     181146
# 6    334890473  PABLO https://soundcloud.com/alexbodoubledolla...     179088
# 7    334887806                          Favorite track on culture       5849
# 8    334859360                                               cool      15301
# 9    334845117                                           DOPE ASF      25732
# 10   334834665                                               DOPE      15301
# 11   334834463                                               cool       1929
# 12   334824892                                 check out my page!     122039
# 13   334821482  Check out my page for diverse beats! @verystro...     225883
# 14   334809500                                    i skate so yeah       5894
# 15   334794306                                              slash      10205
# 16   334749343                        im up believe me believe me     111348
# 17   334733610                               @clarice-garcon: Ikr     127522
# 18   334719340  my mom recently got a very cool Lincoln MKZ Hy...     152321
# 19   334684748                             these hose wishy washy     127522
# 20   334678400              FIRE TRACK I JUST RELEASED ON MY PAGE       3400
# 21   334676848  Hey Go Check Out My Album ! https://soundcloud...     253764
# 22   334664056                       slippery please be excuse me      27556
# 23   334647057  https://soundcloud.com/user-154001124/bando  h...       2553
# 24   334645952                                            littttt       1690
# 25   334644354                                              😣💘👌🤘🌊      15756
# 26   334643893  MASTAPIECE Are The Next Aritst Out of Houston!...     126605
# 27   334638922  Check out my new song youtu.be/wGnGAtH8PCk... ...     214189
# 28   334610431  guys check the mix I just posted... 2017 hip-h...     275842
# 29   334610422  guys check the mix I just posted... 2017 hip-h...     150382
# ..         ...                                                ...        ...
# 709  328125275                                                 🌡🔥     137481
# 710  328108424                                            flames!     194992
# 711  328090794                                             aaaaye      42451
# 712  328087020                                                wop     228340
# 713  328082465  so far my favorite song on the album.... i onl...     116474
# 714  328082463        &gt;&gt;IM BLOWING UP CHECK ME OUT!&lt;&lt;       4440
# 715  328071359                                    GUCCCCCIIIIIIII     212929
# 716  328070989                                My weiner is stinky       2809
# 717  328065331                   @itz_chris-197339224: Fukin rite      53877
# 718  328053686            They dont kno I keep a glock. ITS LIT!!     258161
# 719  328038146                                            ITS LIT      82427
# 720  328038126                                        FUCKIGN LIT      53877
# 721  328038105                           @itz_chris-197339224: YA      53877
# 722  328038061                                    SHIT FUCKIN LIT      53877
# 723  328026065            Everyone FOLLOW ME and I'll FOLLOW BACK     272151
# 724  328014034                                                lit     117492
# 725  328010086                     Bring me in I make beats Migos     184320
# 726  328009505                                       clip please!     220802
# 727  328007076                                              🔥🔥🔥🔥🔥     245959
# 728  327999659                splash.. drip drip.. SPLASH 😂 bruhh      19286
# 729  327997344                                               fire     133584
# 730  327980354                                               Lit!      47614
# 731  327973127                                 follow me for fire      25859
# 732  327970861                                 thats lit as fuck!      40149
# 733  327969495                 tater tott fuck niggas on my radar      42679
# 734  327965963                                                ice      91477
# 735  327965398           love the vision on this album on REPEAT       37268
# 736  327965142                                            🔥🔥🔥🔥🔥🔥🤘       6920
# 737  327961687                                               LGI!      33909
# 738  327961667                                               FIRE      54958
#
#      track_length  spam
# 0          304145     0
# 1          304145     0
# 2          304145     0
# 3          304145     0
# 4          304145     0
# 5          304145     0
# 6          304145     0
# 7          304145     0
# 8          304145     0
# 9          304145     0
# 10         304145     0
# 11         304145     0
# 12         304145     0
# 13         304145     0
# 14         304145     0
# 15         304145     0
# 16         304145     0
# 17         304145     0
# 18         304145     0
# 19         304145     0
# 20         304145     0
# 21         304145     0
# 22         304145     0
# 23         304145     0
# 24         304145     0
# 25         304145     0
# 26         304145     0
# 27         304145     0
# 28         304145     0
# 29         304145     0
# ..            ...   ...
# 709        304145     0
# 710        304145     0
# 711        304145     0
# 712        304145     0
# 713        304145     0
# 714        304145     0
# 715        304145     0
# 716        304145     0
# 717        304145     0
# 718        304145     0
# 719        304145     0
# 720        304145     0
# 721        304145     0
# 722        304145     0
# 723        304145     0
# 724        304145     0
# 725        304145     0
# 726        304145     0
# 727        304145     0
# 728        304145     0
# 729        304145     0
# 730        304145     0
# 731        304145     0
# 732        304145     0
# 733        304145     0
# 734        304145     0
# 735        304145     0
# 736        304145     0
# 737        304145     0
# 738        304145     0
#
# [739 rows x 5 columns]

# %%
# get first 100 tracks
tracks = client.get('/tracks', order='created_at', limit=200)
for track in tracks:
    print(track.title)

# start paging through results, 100 at a time
tracks = client.get('/tracks', order='created_at', limit=200,
                    linked_partitioning=1)
for track in tracks:
    print(track.title)
# Out:
# PitchBattle2dSting
# Dj Kridlokk - Mit Vit Yks Kaks - 1TfSiLUytCQ Fmt135
# Jackman House Basement 26 And 28 Mark
# Spazio Diocesi- La Messa: perchè partecipare?
# HARD (Prod By Chi)
# Kevin R Free
# Il podcast con Vanni Gibertini da Indian Wells (6/3/2017)
# The Inspiration of Caravaggio, with Andrew Graham-Dixon
# And Memories (Outro)
# Karibay ("India" Myth From The Andes)
# All Alone
# Kiss Me Forever
# Il 12 marzo a Libarna "Bambine tra passato e presente".
# Sakura Gakuin -  Davada♪Salad de C'est bon☆Avenue (ダバダ♪サラダ de セボン☆アベニュー) (Cooking Club Minipati)
# Bad Mephisto Pheles lines.
# I Shot The Sheriff - Bob Marley (Instrumental)
# Bangalore D4: Grandstand At Stumps
# Vimma Sweng - Aaltoon seisovaan
# Audio descargado de rtve.es/alacarta
# Alex M.O.R.P.H - Universal Nation 101
# Million reasons (cover)
# The Friday Rock Show (3rd March 2017)
# Slick X Gave It My All.mp3
# Selected Future House Mix
# #4 'Breaking the Myths: Oral Histories' - Hilary Ogbonna
# Hometown
# Futur8000 Mixtape I
# Alternative Rock Sketch #5
# Rahmi Öner & Jay Sean - Maybe (Deep Remix)
# UTWA KUTANGLAH
# GroupSix - Serpent (Preview)
# Eternal Love
# News@5  07-March-2017
# Capitao Tissuda. Comandante CIA. Candido Mota
# Where Is The Law
# BEAT69.WAV
# MINISET - FOREST TECHNOLOGY [ FULLPOWER ]
# TEM LeMAY - Cry On Me
# CrownXP - FireFly (Hip Hop Instrum2017 - 7.3)
# Retro Rock Toni Rae 4 March 2017
# Everest
# Alternative Rock Sketch #5 - No Lead Guitar
# Fujin Mix For POD1
# Rose
# Sounds from 火 evening
# Equinox Sjm 3 2017
# la réalité finalement y'a très peu de gens dedans
# Nause - Tommorow's Just Begun (WhenYourComputerCrashes Remix)
# CHIEU HA VANG.HOANG NGUYEN
# glitchin
# شاهرخی
# Lauren Duffy Best Towie
# Elliott Smith - Between The Bars cover
# Kuishi Kwangu Ni Neema
# Erdinç Emre Eryılmaz - Sen Hep Böyle Kal
# Loi tu trai tim
# Deeper And Deeper
# KOLO
# Музыкальный Экспресс (Иваново FM)11.11.2016-Каспий - Расстояния-Саундтрэки
# LKL01
# Anteeksi Herra Konstaapeli... in]
# Fuckyou
# LKL02
# Mature Porn
# LKL03
# ΑΣΤΑΤΟΣ - Κοιμήσου
# LKL04
# Boletim - 2017 03 02 - Comissão Meio Ambiente
# Instrumental senja
# LKL05
# Collapse 2
# Hillsong Young & Free - Falling Into You (Remix)
# LKL06
# LKL07
# Audio Recording on Tuesday evening
# LKL08
# ПЛЮС СЕМЬ - Летняя
# Robert Johnson - Sweet Home Chicago
# LKL09
# Dangerous
# LKL10
# No Heart {Diss Track}
# Misty Mirage
# Yoe Mase - La Da Dedu (STKD Stadtkind - Remix)
# party-2017 flo-rida-my-house-jogetfunk-erwin-texaz-party-2017
# CSI St Peters Church Lent 2017 - Day_5
# Næstum Tilbuid Kyrrd Með Venjulegu I Byrjun Ogenda
# Definately Not A Nexus Preset
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-db3ebd61d58e> in <module>()
#       7 tracks = client.get('/tracks', order='created_at', limit=200,
#       8                     linked_partitioning=1)
# ----> 9 for track in tracks:
#      10     print(track.title)
#
# TypeError: 'Resource' object is not iterable

# %%
final_comment_list[500]['id']
# Out:
# 330370666

# %%
slippery_track
